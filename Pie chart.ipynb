# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.axis('equal')
exp_value=[2300,3100,1000,2900,30000,10000,50000]
exp_labels=['pent','shirt','tie','rent','pay','electricity','Borrow']
plt.pie(exp_value,labels=exp_labels,radius=1.3,autopct='%0.2f%%',explode=[0,0,.1,0,0,0,0],startangle=180)
plt.show()
